# %% [markdown]
# # Backtesting Trimestral 2025 — Reversión a la Media / RNN-LSTM (input=30, output=90)

# %%
import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib.patches as mpatches

# Añadimos project root, model/cnn y scripts al path
NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = NOTEBOOK_DIR.parents[1]
SCRIPTS_DIR = NOTEBOOK_DIR.parent / "scripts"

for _p in [str(PROJECT_ROOT), str(PROJECT_ROOT / "model" / "cnn"), str(SCRIPTS_DIR)]:
    if _p not in sys.path:
        sys.path.insert(0, _p)

os.environ.setdefault("TF_CPP_MIN_LOG_LEVEL", "2")

import backtest_quarterly_reversion as bt

bt.setup(model_type="lstm", input_window=30, output_window=90)
# Out:
# Entrenando con train_lstm_in30_out90_to2024.run() ...
# Cargando datos desde returns_to2024.parquet ...
# X_train: (12748, 30, 23)  X_val: (1416, 30, 23)  X_test: (1574, 30, 23)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32)             │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 23)             │           759 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,927 (30.96 KB)
#  Trainable params: 7,927 (30.96 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 2/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 3/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 4/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 5/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 6/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 7/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 8/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 9/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 10/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 11/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 12/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 13/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 14/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 15/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 16/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 17/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 18/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 9.9962e-04
# Epoch 19/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 9.8429e-04
# Epoch 20/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 9.7735e-04
# Epoch 21/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 9.7092e-04
# Epoch 22/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 9.5972e-04
# Epoch 23/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 9.5531e-04
# Epoch 24/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - val_loss: 9.4891e-04
# Epoch 25/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.4717e-04
# Epoch 26/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.4193e-04
# Epoch 27/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.3822e-04
# Epoch 28/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.3350e-04
# Epoch 29/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.3193e-04
# Epoch 30/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2522e-04
# Epoch 31/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.3009e-04
# Epoch 32/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2468e-04
# Epoch 33/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2594e-04
# Epoch 34/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2321e-04
# Epoch 35/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2404e-04
# Epoch 36/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2216e-04
# Epoch 37/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2289e-04
# Epoch 38/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.2086e-04
# Epoch 39/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1527e-04
# Epoch 40/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1552e-04
# Epoch 41/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1689e-04
# Epoch 42/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1638e-04
# Epoch 43/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1840e-04
# Epoch 44/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1324e-04
# Epoch 45/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1715e-04
# Epoch 46/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1215e-04
# Epoch 47/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1552e-04
# Epoch 48/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1536e-04
# Epoch 49/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1491e-04
# Epoch 50/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1260e-04
# Epoch 51/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1271e-04
# Epoch 52/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1318e-04
# Epoch 53/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1439e-04
# Epoch 54/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1311e-04
# Epoch 55/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1241e-04
# Epoch 56/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - val_loss: 9.1355e-04
# Modelo cargado: data/rnn/saved_models/rnn_lstm_input30_output90_model.keras
# LSTM: sin escalado de inputs.
# Universo: 23 activos | 2025: 2025-01-02 → 2025-12-31 (250 días)
# Periodos de rebalanceo (4):
#   Q1: 2025-01-02 → 2025-03-31
#   Q2: 2025-04-01 → 2025-06-30
#   Q3: 2025-07-01 → 2025-09-30
#   Q4: 2025-10-01 → 2025-12-31

# %% [markdown]
# ## 1. Universo de activos

# %%
returns_2025 = bt.returns_full.loc["2025"]

print(f"Periodo out-of-sample : {returns_2025.index[0].date()} → {returns_2025.index[-1].date()}")
print(f"Días de trading       : {len(returns_2025)}")
print()
print(f"Activos ({bt.n_assets}):")
print(bt.assets)

# Estadísticas de retorno diario en porcentaje
stats = (returns_2025.describe().T[["mean", "std", "min", "max"]] * 100).round(4)
stats.columns = ["Media diaria (%)", "Vol. diaria (%)", "Mínimo (%)", "Máximo (%)"]
display(stats.sort_values("Media diaria (%)", ascending=False))
# Out:
# Periodo out-of-sample : 2025-01-02 → 2025-12-31
# Días de trading       : 250
#
# Activos (23):
# ['AEP', 'BA', 'CAT', 'CNP', 'CVX', 'DIS', 'DTE', 'ED', 'GD', 'GE', 'HON', 'HPQ', 'IBM', 'IP', 'JNJ', 'KO', 'KR', 'MMM', 'MO', 'MRK', 'MSI', 'PG', 'XOM']
#         Media diaria (%)  Vol. diaria (%)  Mínimo (%)  Máximo (%)
# Ticker
# GE                0.2477           1.9178    -11.7617     10.0466
# CAT               0.1888           2.0022     -9.0315     11.0061
# JNJ               0.1554           1.2355     -7.8953      6.0090
# IBM               0.1295           1.8824     -7.9301     12.1900
# GD                0.1062           1.3355     -7.5513      6.5128
# AEP               0.1030           1.2192     -4.3361      5.9034
# MMM               0.0936           1.8608     -9.6305      8.4124
# CNP               0.0852           1.0415     -3.4862      2.8763
# BA                0.0817           2.3586    -11.0608     14.3010
# MO                0.0668           1.2557     -8.1321      3.5416
# XOM               0.0593           1.4837     -7.4676      4.8710
# KO                0.0580           1.1006     -4.5427      4.6168
# ED                0.0564           1.2524     -3.9206      4.6264
# DTE               0.0397           1.0915     -5.6707      3.0049
# CVX               0.0385           1.5432     -8.5824      6.4342
# MRK               0.0374           1.9157     -9.5070      7.1270
# KR                0.0167           1.6047     -5.1636      9.3894
# DIS               0.0130           1.8698     -9.6905     11.2384
# HON              -0.0263           1.5572     -7.8951      8.5086
# PG               -0.0523           1.1975     -5.1418      3.3199
# MSI              -0.0705           1.4738     -7.9719      5.5365
# IP               -0.1089           2.4770    -13.7508      9.3150
# HPQ              -0.1353           2.4082    -15.9065     10.4080

# %% [markdown]
# ## 2. Señal de reversión a la media en cada rebalanceo

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

for q_idx, (rb_date, ax) in enumerate(zip(bt.rebalance_dates, axes)):
    z = bt.mean_reversion_zscore(rb_date, bt.TRAILING_VOL_DAYS)
    bottom4_idx = set(int(i) for i in np.argsort(z.values)[:bt.N_TOP])
    top4_idx = set(int(i) for i in np.argsort(z.values)[-bt.N_TOP:])
    order = list(np.argsort(z.values))

    sorted_assets = [bt.assets[j] for j in order]
    z_values = [float(z.iloc[j]) for j in order]
    colors = [
        "firebrick" if j in bottom4_idx else "steelblue" if j in top4_idx else "lightgray"
        for j in order
    ]

    bars = ax.barh(sorted_assets, z_values, color=colors, edgecolor="white", height=0.7)
    ax.axvline(0, color="black", lw=1)
    ax.axvline(-1, color="firebrick", lw=0.8, ls=":", alpha=0.8)
    ax.axvline(1, color="steelblue", lw=0.8, ls=":", alpha=0.8)
    ax.set_title(f"Q{q_idx + 1} — {rb_date.strftime('%Y-%m-%d')}", fontsize=12, fontweight="bold")
    ax.set_xlabel("Z-score de log-precio vs media móvil 90d", fontsize=9)
    ax.grid(True, alpha=0.3, axis="x")
    ax.tick_params(axis="y", labelsize=9)

    for bar, val, j in zip(bars, z_values, order):
        if j in bottom4_idx or j in top4_idx:
            x = val + (0.04 if val >= 0 else -0.04)
            ha = "left" if val >= 0 else "right"
            ax.text(
                x, bar.get_y() + bar.get_height() / 2,
                f"{val:.2f}", va="center", ha=ha, fontsize=8, fontweight="bold",
            )

legend_elems = [
    mpatches.Patch(facecolor="firebrick", label="Long: más por debajo de la media"),
    mpatches.Patch(facecolor="steelblue", label="Short: más por encima de la media"),
    mpatches.Patch(facecolor="lightgray", label="No seleccionados"),
]
fig.legend(handles=legend_elems, loc="lower center", ncol=3, fontsize=11, bbox_to_anchor=(0.5, -0.01))
fig.suptitle(
    "Señal de reversión a la media — z-score de log-precio con lookback 90 días",
    fontsize=13, y=1.01,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Ejecución del backtest

# %%
ret_df, holdings = bt.run_backtest()

MODEL_LABEL = bt.MODEL_TYPE.upper() + (" Rel" if bt.RELATIVE and bt.MODEL_TYPE == "cnn" else "")

LABELS = {
    "model_top4_equal":             f"{MODEL_LABEL} Equal",
    "model_top4_riskadjusted":      f"{MODEL_LABEL} Risk-Adj.",
    "model_top4_threshold":         f"{MODEL_LABEL} Umbral",
    "model_top4_propweights":       f"{MODEL_LABEL} Prop.",
    "model_longshort":              f"{MODEL_LABEL} Long-Short",
    "bench_reversion_zscore_90d":   "Reversión z-score 90d",
    "bench_reversion_zscore_input": f"Reversión z-score {bt.INPUT_WINDOW}d",
    "bench_reversion_longshort":    "Reversión Long-Short",
    "bench_equalweight":            "Equal Weight",
}


def format_weights(strategy_name, rb_date):
    pred = bt.predict_at(rb_date)
    vol = bt.trailing_vol(rb_date)
    weights = bt.STRATEGIES[strategy_name](pred=pred, vol=vol, date=rb_date)
    if strategy_name == "bench_equalweight":
        return f"todos (1/{bt.n_assets})"
    if not weights:
        return "cash"
    longs = sorted([asset for asset, weight in weights.items() if weight > 0])
    shorts = sorted([asset for asset, weight in weights.items() if weight < 0])
    if shorts:
        return f"L: {', '.join(longs)} | S: {', '.join(shorts)}"
    return ", ".join(longs)


quarter_names = [f"Q{i+1} ({d.strftime('%b %Y')})" for i, d in enumerate(bt.rebalance_dates)]
rows = {}
for name, label in LABELS.items():
    rows[label] = [format_weights(name, rb_date) for rb_date in bt.rebalance_dates]

sel_df = pd.DataFrame(rows, index=quarter_names).T
display(sel_df)
# Out:
# Q1 (2025-01-02): pred top-4 = ['MO', 'JNJ', 'DIS', 'KO']
# Q2 (2025-04-01): pred top-4 = ['KR', 'MO', 'JNJ', 'MRK']
# Q3 (2025-07-01): pred top-4 = ['MSI', 'HPQ', 'MO', 'XOM']
# Q4 (2025-10-01): pred top-4 = ['HPQ', 'KR', 'MSI', 'PG']
#                                                    Q1 (Jan 2025)  \
# LSTM Equal                                      DIS, JNJ, KO, MO
# LSTM Risk-Adj.                                  DIS, JNJ, KO, MO
# LSTM Umbral                                     DIS, JNJ, KO, MO
# LSTM Prop.                                      DIS, JNJ, KO, MO
# LSTM Long-Short        L: DIS, JNJ, KO, MO | S: AEP, CVX, IP, PG
# Reversión z-score 90d                           ED, GD, HPQ, JNJ
# Reversión z-score 30d                          CAT, HPQ, MO, MSI
# Reversión Long-Short   L: ED, GD, HPQ, JNJ | S: BA, CNP, DIS, KR
# Equal Weight                                        todos (1/23)
#
#                                                      Q2 (Apr 2025)  \
# LSTM Equal                                        JNJ, KR, MO, MRK
# LSTM Risk-Adj.                                    JNJ, KR, MO, XOM
# LSTM Umbral                                       JNJ, KR, MO, MRK
# LSTM Prop.                                        JNJ, KR, MO, MRK
# LSTM Long-Short         L: JNJ, KR, MO, MRK | S: AEP, CNP, DTE, IP
# Reversión z-score 90d                           CAT, DIS, HPQ, MRK
# Reversión z-score 30d                           CAT, DIS, HPQ, MMM
# Reversión Long-Short   L: CAT, DIS, HPQ, MRK | S: CNP, DTE, ED, MO
# Equal Weight                                          todos (1/23)
#
#                                                      Q3 (Jul 2025)  \
# LSTM Equal                                       HPQ, MO, MSI, XOM
# LSTM Risk-Adj.                                    JNJ, KO, MO, MSI
# LSTM Umbral                                      HPQ, MO, MSI, XOM
# LSTM Prop.                                       HPQ, MO, MSI, XOM
# LSTM Long-Short        L: HPQ, MO, MSI, XOM | S: AEP, DIS, IP, MMM
# Reversión z-score 90d                             ED, HPQ, JNJ, PG
# Reversión z-score 30d                             DTE, ED, HPQ, PG
# Reversión Long-Short    L: ED, HPQ, JNJ, PG | S: CAT, GD, HON, IBM
# Equal Weight                                          todos (1/23)
#
#                                                    Q4 (Oct 2025)
# LSTM Equal                                      HPQ, KR, MSI, PG
# LSTM Risk-Adj.                                   KO, KR, MSI, PG
# LSTM Umbral                                     HPQ, KR, MSI, PG
# LSTM Prop.                                      HPQ, KR, MSI, PG
# LSTM Long-Short        L: HPQ, KR, MSI, PG | S: AEP, BA, DTE, ED
# Reversión z-score 90d                           DIS, HON, KO, PG
# Reversión z-score 30d                           BA, CVX, MSI, PG
# Reversión Long-Short   L: DIS, HON, KO, PG | S: CAT, DTE, GD, GE
# Equal Weight                                        todos (1/23)

# %% [markdown]
# ## 4. Retorno acumulado

# %%
cum_value = ret_df.cumsum().apply(np.exp) * 100

STYLE = {
    "model_top4_equal":             dict(color="royalblue",   lw=2.3, ls="-",  label=f"{MODEL_LABEL} Top-4 Equal"),
    "model_top4_riskadjusted":      dict(color="darkorange",  lw=2.3, ls="-",  label=f"{MODEL_LABEL} Top-4 Risk-Adj."),
    "model_top4_threshold":         dict(color="seagreen",    lw=2.3, ls="-",  label=f"{MODEL_LABEL} Top-4 + Umbral"),
    "model_top4_propweights":       dict(color="crimson",     lw=2.0, ls="-",  label=f"{MODEL_LABEL} Top-4 Prop."),
    "model_longshort":              dict(color="black",       lw=2.0, ls="-",  label=f"{MODEL_LABEL} Long-Short"),
    "bench_reversion_zscore_90d":   dict(color="purple",      lw=1.8, ls="-.", label="Reversión z-score 90d"),
    "bench_reversion_zscore_input": dict(color="darkgreen",   lw=1.8, ls=":",  label=f"Reversión z-score {bt.INPUT_WINDOW}d"),
    "bench_reversion_longshort":    dict(color="saddlebrown", lw=1.8, ls="--", label="Reversión Long-Short"),
    "bench_equalweight":            dict(color="gray",        lw=1.8, ls="--", label="Equal Weight (B&H)"),
}

fig, ax = plt.subplots(figsize=(14, 6))
for name, style in STYLE.items():
    ax.plot(cum_value.index, cum_value[name], **style)

for i, rb in enumerate(bt.rebalance_dates[1:], start=2):
    ax.axvline(rb, color="black", lw=0.8, ls=":", alpha=0.6)
    ax.text(rb, ax.get_ylim()[0], f" Q{i}", fontsize=9, color="gray", va="bottom")

ax.axhline(100, color="black", lw=0.8, ls=":")
ax.set_title("Retorno acumulado — Backtesting 2025 vs reversión a la media (base 100)", fontsize=13)
ax.set_xlabel("Fecha")
ax.set_ylabel("Valor cartera")
ax.legend(fontsize=9, loc="upper left", ncol=2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Retorno final (base 100):")
for name, style in STYLE.items():
    final = float(cum_value[name].iloc[-1])
    print(f"  {style['label']:34s}: {final:.2f}  ({final - 100:+.2f} %)")
# Out:
# Retorno final (base 100):
#   LSTM Top-4 Equal                  : 102.34  (+2.34 %)
#   LSTM Top-4 Risk-Adj.              : 108.88  (+8.88 %)
#   LSTM Top-4 + Umbral               : 102.34  (+2.34 %)
#   LSTM Top-4 Prop.                  : 103.01  (+3.01 %)
#   LSTM Long-Short                   : 98.26  (-1.74 %)
#   Reversión z-score 90d             : 119.46  (+19.46 %)
#   Reversión z-score 30d             : 103.07  (+3.07 %)
#   Reversión Long-Short              : 109.84  (+9.84 %)
#   Equal Weight (B&H)                : 113.73  (+13.73 %)

# %% [markdown]
# ## 5. Métricas de rendimiento

# %%
metrics_rows = [bt.compute_metrics(n, ret_df, holdings) for n in bt.STRATEGIES]
metrics = pd.DataFrame(metrics_rows).set_index("strategy")
metrics.index = [LABELS.get(n, n) for n in metrics.index]
metrics.columns = ["Retorno (%)", "Sharpe", "Max DD (%)", "Turnover"]

display(
    metrics.style
    .format({"Retorno (%)": "{:.2f}", "Sharpe": "{:.3f}", "Max DD (%)": "{:.2f}", "Turnover": "{:.3f}"})
    .background_gradient(subset=["Retorno (%)"], cmap="RdYlGn")
    .background_gradient(subset=["Sharpe"],      cmap="RdYlGn")
    .background_gradient(subset=["Max DD (%)"],  cmap="RdYlGn_r")
    .set_caption("Métricas de backtesting 2025")
)

# Gráfico de barras comparativo
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
cols   = ["Retorno (%)", "Sharpe", "Max DD (%)"]
cmaps  = ["RdYlGn", "RdYlGn", "RdYlGn_r"]
titles = ["Retorno total (%)", "Sharpe ratio", "Max Drawdown (%)"]

for ax, col, cmap_name, title in zip(axes, cols, cmaps, titles):
    vals   = metrics[col]
    cmap   = plt.get_cmap(cmap_name)
    norm   = plt.Normalize(vals.min(), vals.max())
    colors = [cmap(norm(v)) for v in vals]
    bars   = ax.bar(range(len(vals)), vals, color=colors, edgecolor="white")
    ax.set_xticks(range(len(vals)))
    ax.set_xticklabels(vals.index, rotation=25, ha="right", fontsize=8)
    ax.set_title(title, fontsize=11)
    ax.grid(True, alpha=0.3, axis="y")
    for bar, v in zip(bars, vals):
        offset = 0.02 if v >= 0 else -0.02
        va = "bottom" if v >= 0 else "top"
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + offset,
                f"{v:.2f}", ha="center", va=va, fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_8874f_row0_col0, #T_8874f_row2_col0 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_8874f_row0_col1, #T_8874f_row2_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_8874f_row0_col2, #T_8874f_row2_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_8874f_row1_col0 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_8874f_row1_col1 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_8874f_row1_col2, #T_8874f_row4_col0, #T_8874f_row4_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8874f_row3_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_8874f_row3_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_8874f_row3_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_8874f_row4_col2 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_8874f_row5_col0, #T_8874f_row6_col2, #T_8874f_row8_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8874f_row5_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_8874f_row5_col2 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_8874f_row6_col0 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_8874f_row6_col1 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_8874f_row7_col0 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_8874f_row7_col1 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_8874f_row7_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_8874f_row8_col0 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_8874f_row8_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8874f">
#   <caption>Métricas de backtesting 2025</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8874f_level0_col0" class="col_heading level0 col0" >Retorno (%)</th>
#       <th id="T_8874f_level0_col1" class="col_heading level0 col1" >Sharpe</th>
#       <th id="T_8874f_level0_col2" class="col_heading level0 col2" >Max DD (%)</th>
#       <th id="T_8874f_level0_col3" class="col_heading level0 col3" >Turnover</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8874f_level0_row0" class="row_heading level0 row0" >LSTM Equal</th>
#       <td id="T_8874f_row0_col0" class="data row0 col0" >2.34</td>
#       <td id="T_8874f_row0_col1" class="data row0 col1" >-0.108</td>
#       <td id="T_8874f_row0_col2" class="data row0 col2" >-14.09</td>
#       <td id="T_8874f_row0_col3" class="data row0 col3" >1.167</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row1" class="row_heading level0 row1" >LSTM Risk-Adj.</th>
#       <td id="T_8874f_row1_col0" class="data row1 col0" >8.88</td>
#       <td id="T_8874f_row1_col1" class="data row1 col1" >0.319</td>
#       <td id="T_8874f_row1_col2" class="data row1 col2" >-10.49</td>
#       <td id="T_8874f_row1_col3" class="data row1 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row2" class="row_heading level0 row2" >LSTM Umbral</th>
#       <td id="T_8874f_row2_col0" class="data row2 col0" >2.34</td>
#       <td id="T_8874f_row2_col1" class="data row2 col1" >-0.108</td>
#       <td id="T_8874f_row2_col2" class="data row2 col2" >-14.09</td>
#       <td id="T_8874f_row2_col3" class="data row2 col3" >1.167</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row3" class="row_heading level0 row3" >LSTM Prop.</th>
#       <td id="T_8874f_row3_col0" class="data row3 col0" >3.01</td>
#       <td id="T_8874f_row3_col1" class="data row3 col1" >-0.064</td>
#       <td id="T_8874f_row3_col2" class="data row3 col2" >-14.83</td>
#       <td id="T_8874f_row3_col3" class="data row3 col3" >1.167</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row4" class="row_heading level0 row4" >LSTM Long-Short</th>
#       <td id="T_8874f_row4_col0" class="data row4 col0" >-1.74</td>
#       <td id="T_8874f_row4_col1" class="data row4 col1" >-0.378</td>
#       <td id="T_8874f_row4_col2" class="data row4 col2" >-13.23</td>
#       <td id="T_8874f_row4_col3" class="data row4 col3" >2.333</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row5" class="row_heading level0 row5" >Reversión z-score 90d</th>
#       <td id="T_8874f_row5_col0" class="data row5 col0" >19.46</td>
#       <td id="T_8874f_row5_col1" class="data row5 col1" >0.641</td>
#       <td id="T_8874f_row5_col2" class="data row5 col2" >-17.72</td>
#       <td id="T_8874f_row5_col3" class="data row5 col3" >1.500</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row6" class="row_heading level0 row6" >Reversión z-score 30d</th>
#       <td id="T_8874f_row6_col0" class="data row6 col0" >3.07</td>
#       <td id="T_8874f_row6_col1" class="data row6 col1" >-0.041</td>
#       <td id="T_8874f_row6_col2" class="data row6 col2" >-23.09</td>
#       <td id="T_8874f_row6_col3" class="data row6 col3" >1.333</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row7" class="row_heading level0 row7" >Reversión Long-Short</th>
#       <td id="T_8874f_row7_col0" class="data row7 col0" >9.84</td>
#       <td id="T_8874f_row7_col1" class="data row7 col1" >0.223</td>
#       <td id="T_8874f_row7_col2" class="data row7 col2" >-17.08</td>
#       <td id="T_8874f_row7_col3" class="data row7 col3" >2.167</td>
#     </tr>
#     <tr>
#       <th id="T_8874f_level0_row8" class="row_heading level0 row8" >Equal Weight</th>
#       <td id="T_8874f_row8_col0" class="data row8 col0" >13.73</td>
#       <td id="T_8874f_row8_col1" class="data row8 col1" >0.653</td>
#       <td id="T_8874f_row8_col2" class="data row8 col2" >-11.33</td>
#       <td id="T_8874f_row8_col3" class="data row8 col3" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6. Análisis de drawdown

# %%
fig, ax = plt.subplots(figsize=(14, 5))

for name, style in STYLE.items():
    cum = ret_df[name].cumsum().apply(np.exp)
    dd  = (cum - cum.cummax()) / cum.cummax() * 100
    ax.fill_between(dd.index, dd, 0, alpha=0.10, color=style["color"])
    ax.plot(dd.index, dd, lw=1.4, color=style["color"], ls=style["ls"], label=style["label"])

for rb in bt.rebalance_dates[1:]:
    ax.axvline(rb, color="black", lw=0.8, ls=":", alpha=0.5)

ax.axhline(0, color="black", lw=0.8)
ax.set_title("Drawdown — Backtesting 2025", fontsize=13)
ax.set_xlabel("Fecha")
ax.set_ylabel("Drawdown (%)")
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=100, decimals=1))
ax.legend(fontsize=8, loc="lower left", ncol=2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Max Drawdown por estrategia:")
for name, style in STYLE.items():
    cum = ret_df[name].cumsum().apply(np.exp)
    dd  = (cum - cum.cummax()) / cum.cummax() * 100
    print(f"  {style['label']:34s}: {float(dd.min()):.2f} %")
# Out:
# Max Drawdown por estrategia:
#   LSTM Top-4 Equal                  : -14.09 %
#   LSTM Top-4 Risk-Adj.              : -10.49 %
#   LSTM Top-4 + Umbral               : -14.09 %
#   LSTM Top-4 Prop.                  : -14.83 %
#   LSTM Long-Short                   : -13.23 %
#   Reversión z-score 90d             : -17.72 %
#   Reversión z-score 30d             : -23.09 %
#   Reversión Long-Short              : -17.08 %
#   Equal Weight (B&H)                : -11.33 %

# %% [markdown]
# ## 7. Interpretación de la reversión a la media
#
# La señal de reversión se calcula con el z-score del log-precio respecto a su media móvil previa, sin usar retornos futuros. Un z-score negativo indica que el activo está por debajo de su media reciente; las variantes long-only compran los valores más alejados por debajo de esa media.
#
# La variante `bench_reversion_zscore_90d` usa una ventana fija de 90 sesiones para capturar desviaciones más estables. `bench_reversion_zscore_input` usa la misma ventana de entrada que el modelo, por lo que compara contra un benchmark clásico con el mismo conjunto de información temporal. `bench_reversion_longshort` añade una pata corta en los activos más alejados por encima de su media, con exposición neta aproximada a cero.
