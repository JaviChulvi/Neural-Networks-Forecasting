# %% [markdown]
# # CNN Deep Conv1D - input 10 / output 90
#
# This notebook trains a CNN Deep Conv1D model for the 10-90 window combination.

# %%
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "util.py").exists():
    PROJECT_ROOT = next(p for p in PROJECT_ROOT.parents if (p / "util.py").exists())

sys.path.insert(0, str(PROJECT_ROOT / "model" / "cnn"))

from cnn_utils import train_cnn_window

EPOCHS = int(os.getenv("CNN_EPOCHS", "120"))
BATCH_SIZE = int(os.getenv("CNN_BATCH_SIZE", "128"))
FORCE_RETRAIN = os.getenv("FORCE_RETRAIN", "0") == "1"

row = train_cnn_window(
    input_window=10,
    output_window=90,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    force=FORCE_RETRAIN,
)

row
# Out:
# SKIP existing result: /Users/higiniopaternaortiz/Master_BME/Neural-Networks-Forecasting/data/cnn/window_results/cnn_input10_output90_results.csv
# {'model': 'CNN_Deep_Conv1D',
#  'input_window': 10,
#  'output_window': 90,
#  'MAE_train': 0.0012671746360161,
#  'MAE_val': 0.0009228644334951,
#  'MAE_test': 0.0012593601302531,
#  'params': 93399,
#  'epochs_trained': 21,
#  'batch_size': 128,
#  'learning_rate': 0.0003,
#  'history_path': 'data/cnn/history/cnn_input10_output90_history.csv',
#  'plot_path': 'data/cnn/plots/cnn_input10_output90_loss_curve.png'}

# %%
import keras
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "util.py").exists():
    PROJECT_ROOT = next(p for p in PROJECT_ROOT.parents if (p / "util.py").exists())

model_path = PROJECT_ROOT / "data" / "cnn" / "saved_models" / "cnn_input10_output90_model.keras"
print(f"Model saved at: {model_path}")

# Load the model for backtesting or inference:
# model = keras.models.load_model(model_path)
# Out:
# Model saved at: /Users/higiniopaternaortiz/Master_BME/Neural-Networks-Forecasting/data/cnn/saved_models/cnn_input10_output90_model.keras
