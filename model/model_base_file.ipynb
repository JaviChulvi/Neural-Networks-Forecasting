# %% [markdown]
# # Modelo
#
# Cargamos los datos desde `util.py`. La función `get_train_test` genera las ventanas train/test para cualquier par (input_window, output_window).

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from util import get_train_test, load_precios_close, load_returns

# %% [markdown]
# ## Datos fuente (cacheados)

# %%
precios_close = load_precios_close()
returns = load_returns()

print(f"precios_close: {precios_close.shape}")
print(f"returns:       {returns.shape}")
precios_close.head()
# Out:
# precios_close: (16186, 23)
# returns:       (16185, 23)
# Ticker           AEP        BA       CAT       CNP       CVX       DIS  \
# Date
# 1962-01-02  0.894096  0.190931  0.462333  0.284116  0.307970  0.057055
# 1962-01-03  0.892467  0.194749  0.466836  0.281340  0.307275  0.057821
# 1962-01-04  0.879439  0.192840  0.478844  0.281340  0.304494  0.057821
# 1962-01-05  0.859895  0.189022  0.483347  0.274553  0.296847  0.058012
# 1962-01-08  0.853381  0.189499  0.486350  0.271468  0.295457  0.057821
#
# Ticker           DTE        ED        GD        GE  ...        IP       JNJ  \
# Date                                                ...
# 1962-01-02  0.386574  0.240809  0.168170  0.617245  ...  0.830127  0.060341
# 1962-01-03  0.383393  0.240809  0.173799  0.611052  ...  0.818794  0.059403
# 1962-01-04  0.380211  0.240066  0.174503  0.603826  ...  0.815961  0.058778
# 1962-01-05  0.372256  0.234863  0.175207  0.588344  ...  0.824461  0.057840
# ...

# %% [markdown]
# ## Ventanas train/test

# %%
d = get_train_test(input_window_size=10, output_window_size=5)

print(f"X_train: {d.X_train.shape}")
print(f"y_train: {d.y_train.shape}")
print(f"X_test:  {d.X_test.shape}")
print(f"y_test:  {d.y_test.shape}")
# Out:
# X_train: (14553, 10, 23)
# y_train: (14553, 23)
# X_test:  (1618, 10, 23)
# y_test:  (1618, 23)
