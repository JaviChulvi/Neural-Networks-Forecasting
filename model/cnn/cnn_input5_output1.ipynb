# %% [markdown]
# # CNN Deep Conv1D - input 5 / output 1
#
# This notebook trains a CNN Deep Conv1D model for the 5-1 window combination.

# %%
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "util.py").exists():
    PROJECT_ROOT = next(p for p in PROJECT_ROOT.parents if (p / "util.py").exists())

sys.path.insert(0, str(PROJECT_ROOT / "model" / "cnn"))

from cnn_utils import train_cnn_window

EPOCHS = int(os.getenv("CNN_EPOCHS", "120"))
BATCH_SIZE = int(os.getenv("CNN_BATCH_SIZE", "128"))
FORCE_RETRAIN = os.getenv("FORCE_RETRAIN", "0") == "1"

row = train_cnn_window(
    input_window=5,
    output_window=1,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    force=FORCE_RETRAIN,
)

row
# Out:
# SKIP existing result: /Users/jchulvi/projects/Neural-Networks-Forecasting/data/cnn/window_results/cnn_input5_output1_results.csv
# {'model': 'CNN_Deep_Conv1D',
#  'input_window': 5,
#  'output_window': 1,
#  'MAE_train': 0.011834775429349,
#  'MAE_val': 0.0090391946835984,
#  'MAE_test': 0.0122369584111652,
#  'params': 93399,
#  'epochs_trained': 28,
#  'batch_size': 128,
#  'learning_rate': 0.0003,
#  'history_path': 'data/cnn/history/cnn_input5_output1_history.csv',
#  'plot_path': 'data/cnn/plots/cnn_input5_output1_loss_curve.png'}
